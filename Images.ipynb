# %%
from PIL import Image

# %%
mac = Image.open('my_computer_image.jpg')

# %%
mac
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=220x165 at 0x7F9363FAE580>

# %%
type(mac)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
mac.size
# Out:
# (220, 165)

# %%
mac.filename
# Out:
# 'my_computer_image.jpg'

# %%
mac.format_description
# Out:
# 'Portable network graphics'

# %%
cropped = mac.crop((0,0,100,100))

# %%
mac.paste(im=cropped,box=(100,0))

# %%
mac
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=220x165 at 0x7F9363FAE580>

# %%
mac.resize((250,300))
# Out:
# <PIL.Image.Image image mode=RGBA size=250x300 at 0x7F9363FDDFA0>

# %%
mac.rotate(90)
# Out:
# <PIL.Image.Image image mode=RGBA size=220x165 at 0x7F93640B23A0>

# %%
#Transparency

# %%
mac.putalpha(0)

# %%
mac
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=220x165 at 0x7F9363FAE580>

# %%
mac.putalpha(255)

# %%
mac
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=220x165 at 0x7F9363FAE580>

# %%
#overlay blue and red
#blue.paste(im=red,box=(0,0),mask=red)
#creates a purple image

# %%
mac.save("test_image.jpg")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/PIL/JpegImagePlugin.py in _save(im, fp, filename)
#     613     try:
# --> 614         rawmode = RAWMODE[im.mode]
#     615     except KeyError as e:
#
# KeyError: 'RGBA'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-23-fa0a2c438791> in <module>
# ----> 1 mac.save("test_image.jpg")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    2156
#    2157         try:
# -> 2158             save_handler(self, fp, filename)
#    2159         finally:
#    2160             # do what we can to clean up
#
# ~/opt/anaconda3/lib/python3.8/site-packages/PIL/JpegImagePlugin.py in _save(im, fp, filename)
# ...
